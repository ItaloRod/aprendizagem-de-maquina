# %% [markdown]
# ### Questão 02

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
dados = pd.read_csv('ex2data1.txt', sep=',', header=None, names=['nota1', 'nota2', 'resultado'])

# %%
dados
# Out:
#         nota1      nota2  resultado
# 0   34.623660  78.024693          0
# 1   30.286711  43.894998          0
# 2   35.847409  72.902198          0
# 3   60.182599  86.308552          1
# 4   79.032736  75.344376          1
# 5   45.083277  56.316372          0
# 6   61.106665  96.511426          1
# 7   75.024746  46.554014          1
# 8   76.098787  87.420570          1
# 9   84.432820  43.533393          1
# 10  95.861555  38.225278          0
# 11  75.013658  30.603263          0
# 12  82.307053  76.481963          1
# 13  69.364589  97.718692          1
# 14  39.538339  76.036811          0
# 15  53.971052  89.207350          1
# 16  69.070144  52.740470          1
# 17  67.946855  46.678574          0
# 18  70.661510  92.927138          1
# 19  76.978784  47.575964          1
# 20  67.372028  42.838438          0
# 21  89.676776  65.799366          1
# 22  50.534788  48.855812          0
# 23  34.212061  44.209529          0
# 24  77.924091  68.972360          1
# ...

# %%
X1 = dados['nota1']
X2 = dados['nota2']
plt.scatter(X1, X2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X1 = dados['nota1']
X2 = dados['nota2']
y = dados['resultado']
plt.scatter(X1, X2, c=y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X = dados[['nota1', 'nota2']]
y = dados['resultado']

# %%
# Dividindo o conjunto de dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Normalizando os dados
mm = MinMaxScaler()
X_train_scaled = mm.fit_transform(X_train)  
X_test_scaled = mm.transform(X_test)

# %%
X_train
# Out:
#         nota1      nota2
# 0   34.623660  78.024693
# 27  93.114389  38.800670
# 51  99.272527  60.999031
# 99  74.775893  89.529813
# 15  53.971052  89.207350
# 2   35.847409  72.902198
# 40  83.902394  56.308046
# 5   45.083277  56.316372
# 53  34.524514  60.396342
# 95  83.489163  48.380286
# 69  66.746719  60.991394
# 39  34.183640  75.237720
# 50  79.944818  74.163119
# 8   76.098787  87.420570
# 14  39.538339  76.036811
# 88  78.635424  96.647427
# 84  80.366756  90.960148
# 21  89.676776  65.799366
# 58  74.248691  69.824571
# 11  75.013658  30.603263
# 4   79.032736  75.344376
# 19  76.978784  47.575964
# 3   60.182599  86.308552
# 92  55.482161  35.570703
# 28  61.830206  50.256108
# 12  82.307053  76.481963
# 32  52.107980  63.127624
# 24  77.924091  68.972360
# 35  54.635106  52.213886
# 7   75.024746  46.554014
# ..        ...        ...
# 42  94.443368  65.568922
# 75  99.827858  72.369252
# 81  94.834507  45.694307
# 97  99.315009  68.775409
# 82  67.319257  66.589353
# ...

# %%
X_train_scaled
# Out:
# array([[0.06236522, 0.69465488],
#        [0.90346048, 0.12008007],
#        [0.99201436, 0.44525373],
#        [0.63975336, 0.86318813],
#        [0.34058025, 0.85846452],
#        [0.0799627 , 0.61961779],
#        [0.77099221, 0.37653763],
#        [0.21277427, 0.37665959],
#        [0.06093951, 0.43642522],
#        [0.76504996, 0.26040749],
#        [0.52429402, 0.44514186],
#        [0.05603775, 0.65382979],
#        [0.71408237, 0.63808845],
#        [0.65877654, 0.83229079],
#        [0.13303819, 0.6655353 ],
#        [0.69525332, 0.96745081],
#        [0.72014983, 0.88414045],
#        [0.85402769, 0.51557164],
#        [0.63217221, 0.57453504],
#        [0.64317242, 0.        ],
#        [0.70096666, 0.65539214],
#        [0.67143087, 0.24862534],
#        [0.42990215, 0.81600135],
#        [0.36230996, 0.07276576],
#        [0.45359469, 0.28788555],
#        [0.74805126, 0.67205614],
#        [0.31378932, 0.47643451],
#        [0.68502437, 0.56205138],
# ...

# %%
X_test
# Out:
#         nota1      nota2
# 63  30.058822  49.592974
# 48  62.073064  96.768824
# 74  58.840956  75.858448
# 87  75.477702  90.424539
# 20  67.372028  42.838438
# 6   61.106665  96.511426
# 26  80.190181  44.821629
# 70  32.722833  43.307173
# 83  57.238706  59.514282
# 10  95.861555  38.225278
# 67  49.072563  51.883212
# 22  50.534788  48.855812
# 71  64.039320  78.031688
# 96  42.261701  87.103851
# 18  70.661510  92.927138
# 76  47.264269  88.475865
# 13  69.364589  97.718692
# 57  32.577200  95.598548
# 46  77.193035  70.458200
# 47  97.771599  86.727822
# 41  51.547720  46.856290
# 37  64.176989  80.908061
# 73  60.457886  73.094998
# 94  89.845807  45.358284
# 91  90.448551  87.508792

# %%
X_test_scaled
# Out:
# array([[-0.00327703,  0.2781716 ],
#        [ 0.45708698,  0.9692291 ],
#        [ 0.41060935,  0.66292255],
#        [ 0.64984535,  0.87629456],
#        [ 0.53328595,  0.17922749],
#        [ 0.44319018,  0.96545859],
#        [ 0.71761068,  0.20827835],
#        [ 0.03503138,  0.18609378],
#        [ 0.38756904,  0.42350432],
#        [ 0.94296466,  0.11165142],
#        [ 0.2701401 ,  0.31172025],
#        [ 0.29116686,  0.26737325],
#        [ 0.4853617 ,  0.69475735],
#        [ 0.17220007,  0.82765132],
#        [ 0.58058862,  0.91295399],
#        [ 0.24413688,  0.84774933],
#        [ 0.56193893,  0.98314328],
#        [ 0.03293718,  0.95208625],
#        [ 0.6745118 ,  0.58381678],
#        [ 0.97043105,  0.82214305],
#        [ 0.3057328 ,  0.23808317],
#        [ 0.48734137,  0.73689201],
#        [ 0.43386076,  0.62244203],
#        [ 0.85645835,  0.21613956],
#        [ 0.8651258 ,  0.83358311]])

# %%
# Utilizando Regressão Logística

# acho que não deve usar max_iter para dados normalizados (mas não tenho certeza)
# melhor valor foi com c=1, para os dados normalizados 

lr = LogisticRegression()

# %%
lr.fit(X_train_scaled, y_train)
lr.score(X_test_scaled,y_test)
# Out:
# 0.88
