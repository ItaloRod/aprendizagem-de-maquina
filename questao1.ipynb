# %% [markdown]
# ## Questão 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit

# %%
df = pd.read_csv('ex1data1.txt', delimiter=',', header=None, names=['x','y'])
df.head(10)
# Out:
#         x        y
# 0  6.1101  17.5920
# 1  5.5277   9.1302
# 2  8.5186  13.6620
# 3  7.0032  11.8540
# 4  5.8598   6.8233
# 5  8.3829  11.8860
# 6  7.4764   4.3483
# 7  8.5781  12.0000
# 8  6.4862   6.5987
# 9  5.0546   3.8166

# %%
X = df['x']
y = df['y']

# %%
plt.scatter(X,y)
plt.show()

# %%
# Regressão linear aplicada
b, m = polyfit(X, y, 1)
plt.plot(X, y, '.')
plt.plot(X, b + m * X, '-')
plt.show()

# %%
# O modelo de regressão linear não seria o mais adequado para representar esses dados,
# as duas variáveis não possuem uma boa correlação. Neste problema seria necessário utilizar
# mais de uma variável X para tentar explicar a variável de saída Y.
